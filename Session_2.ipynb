# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshanhadi0303-lab/ZEESHAN-HADI/blob/main/Session_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conditional Statement

# Comparison Operators
# ==
# >
# <
# >=
# <=
# !=

# %%
x = 5
if x != 5:
    print("True")
else:
    print("False")
# Out:
# False

# %%
a = 7
if a != 7:
    print("Correct")
elif a > 7:
    print("Incorrect")
elif a < 7:
    print("Incorrect2")
else:
    print("Not Correct")
# Out:
# Not Correct

# %%
# Logical Operators:
# and
# or
# not

# %%
age = int(input("Enter your age:"))
gender = input("Enter your gender:")
if age > 18 and gender == "male":
    print("You are allowed for the ride")
else:
    print("You are not allowed")
# Out:
# Enter your age: 25
# Enter your gender: male
# You are allowed for the ride

# %%
age = int(input("Enter your age:"))
gender = input("Enter your gender:")
if age > 18 or gender == "male":
    print("You are allowed for the ride")
else:
    print("You are not allowed")
# Out:
# Enter your age: 16
# Enter your gender: female
# You are not allowed

# %%
math=int(input("Enter Maths Marks"))
urdu=int(input("Enter Urdu Marks"))
eng=int(input("Enter English Marks"))
isl=int(input("Enter Islamiat Marks"))
sin=int(input("Enter Sindhi Marks"))
obtain_Marks=math+urdu+eng+isl+sin
perc = obtain_Marks/500*100
print("Your Percentage is:",perc)
if perc >=80 and perc <= 100:
    print("You have secured A+ Grade")
elif perc >=70 and perc < 80:
    print("You have secured A Grade")
elif perc >=60 and perc < 70:
    print("You have secured B Grade")
elif perc >=50 and perc < 60:
    print("You have secured C Grade")
elif perc >=40 and perc < 50:
    print("You have secured D Grade")
elif perc >=33 and perc < 40:
    print("You have secured E Grade")
elif perc >=0 and perc < 33:
    print("You have secured F Grade")
else:
    print("Your Percentage is wrong")
# Out:
# Enter Maths Marks 300
# Enter Urdu Marks 99
# Enter English Marks 88
# Enter Islamiat Marks 77
# Enter Sindhi Marks 66
# Your Percentage is: 126.0
# Your Percentage is wrong

# %%
# List

# %%
name1= "Daniyal"
name2 = "Wasif"
name3= "Moiz"
name4= "Hanan"

print(name2)

names=["Daniyal","Wasif","Moiz","Hanan"]

print(names[1])
# Out:
# Wasif
# Wasif

# %%
names
# Out:
# ['Daniyal', 'Wasif', 'Moiz', 'Hanan']

# %% [markdown]
# ## **Indexing**

# %%
names[3]
# Out:
# 'Hanan'

# %%
names[-1]
# Out:
# 'Hanan'

# %%
salaries = ['20k','30k','300k','200k','300k']

# %%
salaries
# Out:
# ['20k', '30k', '300k', '200k', '300k']

# %% [markdown]
# ## Slicing

# %%
salaries[1:4]
# Out:
# ['30k', '300k', '200k']

# %%
salaries
# Out:
# ['20k', '30k', '300k', '200k', '300k']

# %%
salaries[-2:-4]
# Out:
# []

# %%
salaries[-2:-5]
# Out:
# []

# %%
salaries[-4:-1]
# Out:
# ['30k', '300k', '200k']

# %%
salaries[2:]
# Out:
# ['300k', '200k', '300k']

# %%
salaries[2:5]
# Out:
# ['300k', '200k', '300k']

# %%
salaries
# Out:
# ['20k', '30k', '300k', '200k', '300k']

# %%
salaries[1:4]
# Out:
# ['30k', '300k', '200k']

# %%
salaries[1:4:2]
# Out:
# ['30k', '200k']

# %%
salaries[:5:3]
# Out:
# ['20k', '200k']

# %%
salaries[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 salaries[6]
#
# IndexError: list index out of range

# %%
type(salaries)
# Out:
# list

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries.append("500k")

# %%
salaries
# Out:
# ['20k', '30k', '300k', '200k', '300k', '500k', '500k']

# %%
len(salaries)
# Out:
# 5

# %%
salaries
# Out:
# ['20k', '30k', '300k', '200k', '300k']

# %%
a = ('20k', '30k', '300k', '200k', '300k')
type(a)
# Out:
# tuple

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries
# Out:
# ['20k', '30k', '300k', '200k', '300k', '500k', '500k']

# %%
salaries.insert(2,"600k")

# %%
salaries
# Out:
# ['20k', '30k', '600k', '300k', '200k', '300k', '500k', '500k']

# %%
salaries[2] = '400k'

# %%
salaries
# Out:
# ['20k', '30k', '400k', '300k', '200k', '300k', '500k', '500k']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
salaries
# Out:
# ['20k', '30k', '400k', '300k', '200k', '300k', '500k', '500k']

# %%
salaries[1:4] = ['20k','30k','40k']

# %%
salaries
# Out:
# ['20k', '20k', '30k', '40k', '200k', '300k', '500k', '500k']

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
a = salaries.copy()

# %%
a
# Out:
# ['20k', '20k', '30k', '40k', '200k', '300k', '500k', '500k']

# %%
salaries.count('500k')
# Out:
# 2

# %%
names
# Out:
# ['Daniyal', 'Wasif', 'Moiz', 'Hanan']

# %%
salaries
# Out:
# ['20k', '20k', '30k', '40k', '200k', '300k', '500k', '500k']

# %%
bio = ['khus',123,True]

# %%
bio
# Out:
# ['khus', 123, True]

# %%
bio.extend(salaries)

# %%
bio
# Out:
# ['khus', 123, True, '20k', '20k', '30k', '40k', '200k', '300k', '500k', '500k']

# %%
bio.Append('200k')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 bio.Append('200k')
#
# AttributeError: 'list' object has no attribute 'Append'

# %%
bio.append('200k')

# %%
bio
# Out:
# ['khus',
#  123,
#  True,
#  '20k',
#  '20k',
#  '30k',
#  '40k',
#  '200k',
#  '300k',
#  '500k',
#  '500k',
#  '200k']
