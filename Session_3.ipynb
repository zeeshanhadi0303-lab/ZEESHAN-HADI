# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshanhadi0303-lab/ZEESHAN-HADI/blob/main/Session_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List in List
bios = ["khush",26,"DS","khush@gmail.com",["sana",23,"DA","sana@gmail.com"],57]
bios
# Out:
# ['khush',
#  26,
#  'DS',
#  'khush@gmail.com',
#  ['sana', 23, 'DA', 'sana@gmail.com'],
#  57]

# %%
len(bios)
# Out:
# 6

# %%
bios[4][3]
# Out:
# 'sana@gmail.com'

# %%
# List in List
bios = ["khush",26,"DS","khush@gmail.com",["sana",23,"DA",[1,2,3],"sana@gmail.com"],57]
bios
# Out:
# ['khush',
#  26,
#  'DS',
#  'khush@gmail.com',
#  ['sana', 23, 'DA', [1, 2, 3], 'sana@gmail.com'],
#  57]

# %%
bios[4][3][-1]
# Out:
# 3

# %%
bios[4][:3]
# Out:
# ['sana', 23, 'DA']

# %% [markdown]
# ## ***Strings***

# %% [raw]
# " "
# ' '
# ''' '''
# """ """

# %%
'We have been comp 3
session'
# Out:
#   Cell In[15], line 1
#     'We have been comp 3
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''We have been comp 3
session'''
# Out:
# 'We have been comp 3 \nsession'

# %%
print('''We have been comp 3
session''')
# Out:
# We have been comp 3
# session

# %%
print("""We have been comp 3
session""")
# Out:
# We have been comp 3
# session

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
"     hell world    "
# Out:
# '     hell world    '

# %%
"     hell world     ".strip()
# Out:
# 'hell world'

# %%
"     hell world    ".rstrip()
# Out:
# '     hell world'

# %%
"     hell world    ".lstrip()
# Out:
# 'hell world    '

# %%
["We have been comp 3 session"].split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 ["We have been comp 3 session"].split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
"We have been comp 3 session".split()
# Out:
# ['We', 'have', 'been', 'comp', '3', 'session']

# %%
"khushboosaleem@gmail.com".split('@')
# Out:
# ['khushboosaleem', 'gmail.com']

# %%
"khushboosaleem@gmail.com".split('.')
# Out:
# ['khushboosaleem@gmail', 'com']

# %%
text = "  Hello World  "

# %%
text
# Out:
# '  Hello World  '

# %%
print(text.upper())
# HELLO WORLD
# Out:
#   HELLO WORLD

# %%
text
# Out:
# '  Hello World  '

# %%
text = text.upper()

# %%
text
# Out:
# '  HELLO WORLD  '

# %%
text.lower()
# Out:
# '  hello world  '

# %%
"We have been comp 3 session".replace("3","2")
# Out:
# 'We have been comp 2 session'

# %%
txt = "We have been comp 3 session"
txt
# Out:
# 'We have been comp 3 session'

# %%
txt.replace()

# %%
txt
# Out:
# 'We have been comp 3 session'

# %%
txt[2]
# Out:
# ' '

# %%
txt[1] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 txt[1] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # ***Tuple***

# %%
tuple_bios = ("khush",26,"DS","khush@gmail.com",("sana",23,"DA","sana@gmail.com"),57)
tuple_bios
# Out:
# ('khush',
#  26,
#  'DS',
#  'khush@gmail.com',
#  ('sana', 23, 'DA', 'sana@gmail.com'),
#  57)

# %%
tuple_bios[2]
# Out:
# 'DS'

# %%
tuple_bios[2] = "DA"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 tuple_bios[2] = "DA"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple_bio = ("khush",26,"DS","khush@gmail.com",["sana",23,"DA","sana@gmail.com"],57)

# %%
tuple_bio[4]
# Out:
# ['sana', 23, 'DA', 'sana@gmail.com']

# %%
tuple_bio[4][1]
# Out:
# 23

# %%
tuple_bio[4][1] = '24'

# %%
tuple_bio
# Out:
# ('khush',
#  26,
#  'DS',
#  'khush@gmail.com',
#  ['sana', '24', 'DA', 'sana@gmail.com'],
#  57)

# %%
num1 = (1,4)
num2 = (5,7)

# %%
num1 * 3
# Out:
# (1, 4, 1, 4, 1, 4)

# %%
num1 + num2
# Out:
# (1, 4, 5, 7)

# %%
# Unpacking
tuple_bio
# Out:
# ('khush',
#  26,
#  'DS',
#  'khush@gmail.com',
#  ['sana', '24', 'DA', 'sana@gmail.com'],
#  57)

# %%
name,age,des,email,other_info,num = tuple_bio

# %%
name
# Out:
# 'khush'

# %%
age
# Out:
# 26

# %%
num
# Out:
# 57

# %%
name,age,des,email,other_info = tuple_bio
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 name,age,des,email,other_info = tuple_bio
#
# ValueError: too many values to unpack (expected 5)

# %%
name,age,des,email,*other_info = tuple_bio

# %%
other_info
# Out:
# [['sana', '24', 'DA', 'sana@gmail.com'], 57]

# %%
tuple_bio
# Out:
# ('khush',
#  26,
#  'DS',
#  'khush@gmail.com',
#  ['sana', '24', 'DA', 'sana@gmail.com'],
#  57)

# %%
name,age,des,*email,other_info = tuple_bio

# %%
email
# Out:
# ['khush@gmail.com', ['sana', '24', 'DA', 'sana@gmail.com']]
