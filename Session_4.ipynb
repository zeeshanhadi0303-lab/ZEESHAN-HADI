# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshanhadi0303-lab/ZEESHAN-HADI/blob/main/Session_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
val1 = int(input("Enter Value 1"))
val2 = int(input("Enter Value 2"))
op = input("Enter Operator")
if op == "+":
    print(val1 + val2)
elif op == "-":
    print(val1 - val2)
elif op == "x":
    print(val1 * val2)
elif op == "/":
    print(val1 / val2)
else:
    print("Please Enter Correct Operator")
# Out:
# Enter Value 1 15
# Enter Value 2 20
# Enter Operator x
# 300

# %%
# For Loop

# %%
cleanCities = ["Karachi","Lahore","Sukkur","Multan","Quetta"]
cleanCities
# Out:
# ['Karachi', 'Lahore', 'Sukkur', 'Multan', 'Quetta']

# %%
print(cleanCities[0])
print(cleanCities[1])
print(cleanCities[2])
print(cleanCities[3])
print(cleanCities[4])
# Out:
# Karachi
# Lahore
# Sukkur
# Multan
# Quetta

# %%
for cityToCheck in cleanCities:
    print(cityToCheck)
# Out:
# Karachi
# Lahore
# Sukkur
# Multan
# Quetta

# %%
cleanCities = ["Karachi","Lahore","Sukkur","Multan","Quetta"]
cityName = input("Enter city Name:")
for cityToCheck in cleanCities:
    if cityName == cityToCheck:
        print("It is a clean city")
# Out:
# Enter city Name: islamabad

# %%
# Nested For Loop

# %%
firstName = ["Ali","Abid","Adnan"]
lastName = ["Ahmed","Anjum","Azad"]
for first in firstName:
    for last in lastName:
        print(first + " " + last)
# Out:
# Ali Ahmed
# Ali Anjum
# Ali Azad
# Abid Ahmed
# Abid Anjum
# Abid Azad
# Adnan Ahmed
# Adnan Anjum
# Adnan Azad

# %%
# While Loop

a = 0
while a < 5:
    print(a)
    a += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
cities_to_visit = []
user_input = ''

while user_input != 'quit':
    city = input('Enter city to visit:')
    if city == 'quit':
        user_input = 'quit'
    else:
        cities_to_visit.append(city)
# Out:
# Enter city to visit: karachi
# Enter city to visit: multan
# Enter city to visit: quit

# %%
print(cities_to_visit)
# Out:
# ['karachi', 'multan']

# %% [markdown]
# ## Dictionary

# %% [raw]
# my_dict = {
#     key:value,
#     key:value
# }

# %%
my_dict = {
    "name":"khushboo saleem",
    "Position":"DS",
    "Employee Status":True
}

# %%
my_dict
# Out:
# {'name': 'khushboo saleem', 'Position': 'DS', 'Employee Status': True}

# %%
my_dict["name"]
# Out:
# 'khushboo saleem'

# %%
my_dict["Name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 my_dict["Name"]
#
# KeyError: 'Name'

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
type(my_dict)
# Out:
# dict

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
my_dict.get("name")
# Out:
# 'khushboo saleem'

# %%
my_dict1 = {
    "name":"khushboo saleem",
    "Position":"DS",
    "Employee Status":True,
    "name":"sara"
}

# %%
my_dict1
# Out:
# {'name': 'sara', 'Position': 'DS', 'Employee Status': True}

# %%
my_dict
# Out:
# {'name': 'khushboo saleem', 'Position': 'DS', 'Employee Status': True}

# %%
my_dict['name']
# Out:
# 'khushboo saleem'

# %%
my_dict['name'] = "sara"

# %%
my_dict
# Out:
# {'name': 'sara', 'Position': 'DS', 'Employee Status': True}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
my_dict.update({'Position':"DA"})

# %%
my_dict
# Out:
# {'name': 'sara', 'Position': 'DA', 'Employee Status': True}

# %%
my_dict.update({'email':"khush@gmail.com"})

# %%
my_dict
# Out:
# {'name': 'sara',
#  'Position': 'DA',
#  'Employee Status': True,
#  'email': 'khush@gmail.com'}

# %%
my_dict['number'] = "032453645"

# %%
my_dict
# Out:
# {'name': 'sara',
#  'Position': 'DA',
#  'Employee Status': True,
#  'email': 'khush@gmail.com',
#  'number': '032453645'}

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'Position', 'Employee Status', 'email', 'number'])

# %%
my_dict.values()
# Out:
# dict_values(['sara', 'DA', True, 'khush@gmail.com', '032453645'])

# %%
my_dict.items()
# Out:
# dict_items([('name', 'sara'), ('Position', 'DA'), ('Employee Status', True), ('email', 'khush@gmail.com'), ('number', '032453645')])

# %%
Employee = {
    101 : {"name":"sara","age":25,"salary":40000},
    102 : {"name":"sana","age":28,"salary":50000},
    103 : {"name":"sadia","age":37,"salary":60000}
}

# %%
Employee
# Out:
# {101: {'name': 'sara', 'age': 25, 'salary': 40000},
#  102: {'name': 'sana', 'age': 28, 'salary': 50000},
#  103: {'name': 'sadia', 'age': 37, 'salary': 60000}}

# %%
Employee[102]
# Out:
# {'name': 'sana', 'age': 28, 'salary': 50000}

# %%
Employee[102]["salary"]
# Out:
# 50000

# %%
Employee1 = {
    101 : ["name","sara","age",25,"salary",40000],
    102 : {"name":"sana","age":28,"salary":50000},
    103 : {"name":"sadia","age":37,"salary":60000}
}

# %%
Employee1[101][-1]
# Out:
# 40000

# %%
Employee
# Out:
# {101: {'name': 'sara', 'age': 25, 'salary': 40000},
#  102: {'name': 'sana', 'age': 28, 'salary': 50000},
#  103: {'name': 'sadia', 'age': 37, 'salary': 60000}}

# %%
Employee.items()
# Out:
# dict_items([(101, {'name': 'sara', 'age': 25, 'salary': 40000}), (102, {'name': 'sana', 'age': 28, 'salary': 50000}), (103, {'name': 'sadia', 'age': 37, 'salary': 60000})])

# %%
for key,value in Employee.items():
    print(value['name'])
# Out:
# sara
# sana
# sadia

# %%
for i in Employee.values():
    print(i['name'])
# Out:
# sara
# sana
# sadia

# %%
for i in Employee:
    print(Employee[i]['name'])
# Out:
# sara
# sana
# sadia

# %% [markdown]
# ## Set

# %%
fruit = {"apple","apple","banana","banana","grapes"}

# %%
fruit
# Out:
# {'apple', 'banana', 'grapes'}

# %%
fruit[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 fruit[1]
#
# TypeError: 'set' object is not subscriptable

# %%
dir(set())
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
num = {1,4,6,2,5,5,5,7,10,4,3,1}

# %%
num
# Out:
# {1, 2, 3, 4, 5, 6, 7, 10}

# %%
num_list = list({1,4,6,2,5,5,5,7,10,4,3,1})

# %%
num_list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 10]

# %%
num_tup = tuple({1,4,6,2,5,5,5,7,10,4,3,1})

# %%
num_tup
# Out:
# (1, 2, 3, 4, 5, 6, 7, 10)

# %%
# pop
# remove
# union
# add
# 'symmetric_difference'
# 'symmetric_difference_update'
