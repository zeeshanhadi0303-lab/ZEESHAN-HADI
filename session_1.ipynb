# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshanhadi0303-lab/ZEESHAN-HADI/blob/main/session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World Again")
# Out:
# Hello World Again

# %%
"Hello World" #string

# %%
123 #int

# %%
23.56 #float

# %%
True False # Boolean

# %%
a = 5
b = 6
c = a+b
print(c)
# Out:
# 11

# %%
x = "ali"
y = 10
z = x+y
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 x = "ali"
#       2 y = 10
# ----> 3 z = x+y
#       4 print(z)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = "9"
b = 6
c = a+b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 a = "9"
#       2 b = 6
# ----> 3 c = a+b
#       4 print(c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
f = "Khushboo"
g = "Saleem"
h = f+" "+g
print(h)
# Out:
# Khushboo Saleem

# %%
a = "ali"
a = "mughal"
print(a)
# Out:
# mughal

# %%
a = "7"
b = 5
c = a*b
print(c)
# Out:
# 77777

# %%
x = 10
y = x%3
print(y)
# Out:
# 1

# %%
a = "5"
b = 3
c = a-b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 a = "5"
#       2 b = 3
# ----> 3 c = a-b
#       4 print(c)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
x = "8"
y = 4
z = x/y
print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 x = "8"
#       2 y = 4
# ----> 3 z = x/y
#       4 print(z)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
2**3
# Out:
# 8

# %%
2 + 2j  # Complex
# Out:
# (2+2j)

# %%
type(2 + 2j)
# Out:
# complex

# %%
type("123")
# Out:
# str

# %% [markdown]
# # Typecasting

# %%
type(123)
# Out:
# int

# %%
int("123")
# Out:
# 123

# %%
float("123.45")
# Out:
# 123.45

# %%
int('123.45')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 int('123.45')
#
# ValueError: invalid literal for int() with base 10: '123.45'

# %%
int(123.45)
# Out:
# 123

# %%
str(234)
# Out:
# '234'

# %%
print('ali's house')
# Out:
#   Cell In[32], line 1
#     print('ali's house')
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("ali's house")
# Out:
# ali's house

# %%
print('ali\'s house')
# Out:
# ali's house
